# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，這是一個非常經典的科學問題！這主要是因為**太陽光**、**地球大氣層**以及**我們的眼睛**三者共同作用的結果。
#
# 以下為您用簡單易懂的步驟來解釋：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然我們看到的太陽光好像是白色的，但它其實是由**紅、橙、黃、綠、藍、靛、紫**等所有彩虹的顏色混合而成的。
# 這些光以「光波」的形式傳播，不同顏色的光，波長也不同：
# *   **紅光、黃光**：波長較**長**。
# *   **藍光、紫光**：波長較**短**。
#
# ### 2. 大氣層的「阻擋」與「散射」
# 地球周圍包圍著厚厚的大氣層，裡面充滿了氣體分子（主要是氮氣和氧氣）。
# 當太陽光穿過大氣層時，會撞擊到這些微小的氣體分子，這時就會發生一種物理現象，叫做**「瑞利散射」（Rayleigh scattering）**：
# *   **波長較長的光（如紅光、黃光）**：像大卡車一樣，可以直接穿過這些微小的氣體分子，不太受到影響。
# *   **波長較短的光（如藍光、紫光）**：像小皮球一樣，碰到氣體分子就會被撞得**向四面八方散射開來**。
#
# 因為藍光在空氣中到處亂飛、充斥了整個天空，當我們抬頭看時，這些被散射的藍光進入了我們的眼睛，所以天空看起來就是藍色的。
#
# ---
#
# ### 💡 一個有趣的延伸問題：為什麼天空不是「紫色」的？
# 既然紫光的波長比藍光更短，被散射得更厲害，那為什麼天空不是紫色的，而是藍色的呢？
#
# 這有兩個主要原因：
# 1.  **太陽光的成分**：太陽光中本來就含有比較多的藍光，紫光的比例相對較少。
# 2.  **人類眼睛的構造**：我們人類的視網膜上有三種辨色細胞（紅、綠、藍）。我們的眼睛對**藍光**的敏感度遠遠高於紫光。所以，即使天空中有一些紫光，我們的大腦和眼睛還是會把它自動忽略，主要接收到藍色。
#
# ---
#
# ### 🌅 為什麼傍晚的夕陽是紅色的？
# 這也跟散射有關！
# 在日出或日落時，太陽的位置很低，陽光必須穿過**更厚**的大氣層才能到達我們的眼睛。
# 在這個漫長的過程中，藍光在半路上就已經被散射光了，根本無法到達我們的眼睛；只有穿透力最強的**紅光和橙光**能夠穿透厚厚的大氣層，所以夕陽看起來就是美麗的紅橙色。
