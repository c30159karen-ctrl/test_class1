# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為一個物理現象，叫做**「瑞利散射」（Rayleigh scattering）**。
#
# 這可以拆解成以下幾個簡單的步驟來理解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然我們看到的太陽光好像是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有顏色的光混合而成的。這些光以「波」的形式傳播：
# *   **紅色、黃色光**：波長較**長**（像大浪），不容易被阻擋。
# *   **藍色、紫色光**：波長較**短**（像小漣漪），很容易受到干擾。
#
# ### 2. 遇上地球的大氣層
# 地球周圍包圍著一層厚厚的大氣層，裡面充滿了氮氣、氧氣等氣體分子，以及微小的塵埃。
#
# ### 3. 關鍵的「散射」過程
# 當太陽光穿過大氣層時，光線會撞擊到這些氣體分子：
# *   波長較長的**紅光、黃光**穿透力強，可以像沒事一樣直接穿過大氣直達地面。
# *   波長較短的**藍光**，一碰到氣體分子就會像打撞球一樣，**向四面八方彈射（散射）開來**。
# *   這些被撞得亂飛的藍光充滿了整個天空，當我們抬頭看時，眼睛接收到的就是這些被散射的藍光，所以天空看起來就是藍色的。
#
# ---
#
# ### 🤔 常見疑問：那為什麼天空不是「紫色」的？
# 紫光的波長比藍光更短，按理來說散射得更厲害，天空為什麼不是紫色的？
# 這有兩個主要原因：
# 1.  **太陽光本身的成分**：太陽光中藍光的比例本來就比紫光多。
# 2.  **人類眼睛的限制**：人眼對藍色光非常敏感，而對紫色光比較遲鈍。因此，即使天空中有一些紫光，我們的大腦也會自動將它忽略，呈現出美麗的藍色。
#
# ---
#
# ### 💡 順便想想：為什麼夕陽是紅色的？
# 傍晚太陽下山時，陽光是斜射過來的，必須穿過**比中午厚很多**的大氣層。
# 這時，藍光在半路上就已經被散射殆盡、看不到了；只有穿透力最強的**紅光和橙光**能穿透重重大氣到達我們的眼睛，所以夕陽看起來就是紅紅橘橘的。
